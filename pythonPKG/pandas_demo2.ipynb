# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt  
import seaborn as sns
print('==end==')
# Out:
# ==end==

# %%
titanic = pd.read_csv("http://y.biomooc.com/wangjl/docs/seaborn-data/titanic.csv")
print(titanic.shape) #(891, 15)
titanic.head()
# Out:
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null object
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null object
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.3+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#embark_town 有几个?
titanic['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %% [markdown]
# # explore

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['adult_male'].value_counts().plot(kind='pie', figsize=(6,6))

# %%
titanic['embarked'].value_counts().plot(kind='pie')

# %%
titanic['fare'].plot(kind="density", figsize=(14,6)) #密度曲线

# %%
ax=titanic['age'].plot(kind='density', figsize=(14,6))
#添加竖线
ax.axvline(titanic['age'].mean(), color='red') #平均线
ax.axvline(titanic['age'].median(), color='green') #中位数
ax.axvline(x=.5, ymin=0.25, ymax=0.75, linewidth=20, color="#FF0000", alpha=0.2) #alpha不透明度

# %%
help(ax.axvline)
# Out:
# Help on method axvline in module matplotlib.axes._axes:
#
# axvline(x=0, ymin=0, ymax=1, **kwargs) method of matplotlib.axes._subplots.AxesSubplot instance
#     Add a vertical line across the axes.
#
#     Parameters
#     ----------
#     x : scalar, optional, default: 0
#         x position in data coordinates of the vertical line.
#
#     ymin : scalar, optional, default: 0
#         Should be between 0 and 1, 0 being the bottom of the plot, 1 the
#         top of the plot.
#
#     ymax : scalar, optional, default: 1
#         Should be between 0 and 1, 0 being the bottom of the plot, 1 the
#         top of the plot.
#
#     Returns
#     -------
#     line : `~matplotlib.lines.Line2D`
#
#     Other Parameters
#     ----------------
#     **kwargs
#         Valid keyword arguments are `.Line2D` properties, with the
#         exception of 'transform':
#
#         Properties:
# ...

# %%
titanic['fare'].head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: fare, dtype: float64

# %%
titanic['fare'].plot(kind="hist",bins=100, figsize=(14,6)) #直方图

# %%
#散点图
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
titanic.plot(kind='scatter', x="age",y='fare', figsize=(6,6)) #散点图

# %%
ax=titanic['who'].value_counts().plot(kind='bar', figsize=(6,4))
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
a1=titanic[ 'who'].value_counts()
print(a1)
a1.plot(kind='box', by='who', figsize=(6,4))
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
titanic[ ['who','pclass'] ].plot(kind='box', by="pclass", figsize=(6,4)) #怎么使用多个盒子呢？//todo

# %%
help(titanic.plot)
# Out:
# Help on FramePlotMethods in module pandas.plotting._core object:
#
# class FramePlotMethods(BasePlotMethods)
#  |  DataFrame plotting accessor and method
#  |
#  |  Examples
#  |  --------
#  |  >>> df.plot.line()
#  |  >>> df.plot.scatter('x', 'y')
#  |  >>> df.plot.hexbin()
#  |
#  |  These plotting methods can also be accessed by calling the accessor as a
#  |  method with the ``kind`` argument:
#  |  ``df.plot(kind='line')`` is equivalent to ``df.plot.line()``
#  |
#  |  Method resolution order:
#  |      FramePlotMethods
#  |      BasePlotMethods
#  |      pandas.core.base.PandasObject
#  |      pandas.core.base.StringMixin
#  |      pandas.core.accessor.DirNamesMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
# ...

# %% [markdown]
# # correlation

# %%
corr=titanic.corr()
corr
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
fig=plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu',fignum=fig.number)

plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical') #x轴文字翻转
plt.yticks(range(len(corr.columns)), corr.columns); #y轴文字

# %%
titanic.plot(kind='scatter', x='fare',y='age')

# %%
ax=titanic[['fare', 'sex']].boxplot(by="sex", figsize=(10,6))
ax.set_ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %% [markdown]
# # filter

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#一等舱的生存率
a=titanic.loc[titanic['pclass']==1, 'survived']; 
a.sum()/a.shape[0]
# Out:
# 0.6296296296296297

# %%
#每个仓位的生存率
for i in range(1,4):
    a=titanic.loc[titanic['pclass']==i, 'survived']; 
    ratio=a.sum()/a.shape[0]
    print(i, ratio)
# Out:
# 1 0.6296296296296297
# 2 0.47282608695652173
# 3 0.24236252545824846

# %%
#找出老人和孩子
a1=titanic.loc[ (titanic['age']<15) | (titanic['age']>60)]
print(titanic.shape[0], a1.shape) #(100, 15)
a1.head()
# Out:
# 891 (100, 15)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 14  child       False  NaN  Southampton    no   True
# 16  child       False  NaN   Queenstown    no  False

# %%
# 找出在一等舱的孩子
a2=titanic.loc[ (titanic['age']<15) & (titanic['pclass']==1)]
print(a2.shape[0]) #5
a2.head()
# Out:
# 5
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 305         1       1    male   0.92      1      2  151.5500        S  First
# 435         1       1  female  14.00      1      2  120.0000        S  First
# 445         1       1    male   4.00      0      2   81.8583        S  First
# 802         1       1    male  11.00      1      2  120.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 297  child       False    C  Southampton    no  False
# 305  child       False    C  Southampton   yes  False
# 435  child       False    B  Southampton   yes  False
# 445  child       False    A  Southampton   yes  False
# 802  child       False    B  Southampton   yes  False

# %%
#生存率， 按照仓位、性别区分
titanic.pivot_table('survived', 'pclass','sex')
# Out:
# sex       female      male
# pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
a3=titanic.loc[titanic['who']=='child']
print(titanic.shape[0], a3.shape[0])
a3.head()
# Out:
# 891 83
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 14  child       False  NaN  Southampton    no   True
# 16  child       False  NaN   Queenstown    no  False

# %%
titanic.pivot_table('survived', 'pclass','who')
# Out:
# who        child       man     woman
# pclass
# 1       0.833333  0.352941  0.978022
# 2       1.000000  0.080808  0.909091
# 3       0.431034  0.119122  0.491228

# %%
## 每个仓位中年龄最大的
for i in titanic['pclass'].unique():
    rs=titanic.loc[ (titanic['pclass']==i), 'age'].max()
    print(i,rs)
# Out:
# 3 74.0
# 1 80.0
# 2 70.0

# %%
#直接执行shell命令
! pwd
# Out:
# /home/wangjl/test

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 转置行和列
nlist=['artical 1','a20','a30','a40','a50']
plist=[10,20,30,40,50]
clist=['评论1','评论2','评论3','评论4','评论5']

df=pd.DataFrame( data={'name':nlist, 'price':plist, 'comment':clist} )
df
# Out:
#         name  price comment
# 0  artical 1     10     评论1
# 1        a20     20     评论2
# 2        a30     30     评论3
# 3        a40     40     评论4
# 4        a50     50     评论5

# %%
df.T
# Out:
#                  0    1    2    3    4
# name     artical 1  a20  a30  a40  a50
# price           10   20   30   40   50
# comment        评论1  评论2  评论3  评论4  评论5
